// %% [markdown]
// # 3 References, Recursion, and Lists

// %%
char c = 'H';
int x = c;
System.out.println(c); // This will print 72 to the console.
System.out.println(x);
// Out:
// H
// 72

// %%
int x;
double y;

// %%
x = -1431195969;
y = 567213.112;

// %%
int x = 5;
int y;
y = x; /*Put x value to y's bit*/
x = 2;
System.out.println("x is: " + x);
System.out.println("y is: " + y);
// Out:
// x is: 2
// y is: 5

// %%
public static class Walrus {
    public int weight;
    public double tuskSize;

    public Walrus(int w, double ts) {
        weight = w;
        tuskSize = ts;
    }
}
Walrus w1 = new Walrus(1000, 2.5);
System.out.println(w1.weight); // This will print 1000 to the console.
System.out.println(w1.tuskSize); // This will print 2.5 to the
// Out:
// 1000
// 2.5

// %%
Walrus a = new Walrus(1000, 8.3);
Walrus b;
b = a;

// %%
public static double average(double a, double b) {
    return (a + b) / 2;
}
System.out.println(average(4.0, 8.0)); // This will print
// Out:
// 6.0

// %%
public static void main(String[] args) {
    double x = 5.5;
    double y = 10.0;
    double avg = average(x, y);
    System.out.println("The average is: " + avg);   
}

// %%
public class PassByValueFigure {
    public static void main(String[] args) {
           Walrus walrus = new Walrus(3500, 10.5);
           int x = 9;

           doStuff(walrus, x);
           System.out.println(walrus.weight);
           System.out.println(x);
    }

    public static void doStuff(Walrus W, int x) {
           W.weight = W.weight - 100;
           x = x - 5;
    }
}
System.out.println("After doStuff:");
PassByValueFigure.main(null);
// Out:
// After doStuff:
// 3400
// 9

// %%
public class iterativeSize() {
    IntList p = this;
    int totalSize = 0;
    while (p != null) {
        totalSize = totalSize + 1;
        p = p.next;
    }
    return totalSize;
}
// Out:
// |   public class iterativeSize() {
// '{' expected
//
// |       while (p != null) {
// illegal start of type
//
// |       while (p != null) {
// <identifier> expected
//
// |       return totalSize;
// illegal start of type
//
// |       return totalSize;
// <identifier> expected
