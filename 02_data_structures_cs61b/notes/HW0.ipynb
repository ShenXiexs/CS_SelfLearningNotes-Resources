// %% [markdown]
// # HW 0: A Java Crash Course
// https://sp19.datastructur.es/materials/hw/hw0/hw0.html

// %%
public class ClassNameHere {
    public static void main(String[] args) {
        int x = 5;
        if (x<10)
            x = x + 10;
        if (x<10)
            x = x + 10;
        System.out.println(x);
    }
}
ClassNameHere.main(null);
// Out:
// 15

// %%
public class ConditionalsWithBlocks {
    public static void main(String[] args) {
        int x = 5;
        if (x<10){
            System.out.println("I shall increase x by 10");
            x = x + 10;            
        }

        if (x<10){
            System.out.println("I shall increase x by 10");
            x = x + 10;
        }
        System.out.println(x);
    }
}
ConditionalsWithBlocks.main(null);
// Out:
// I shall increase x by 10
// 15

// %%
public class PrintAbsoluteValue {
    public static void main(String[] args) {
        int x = 5;

        if (x < 0)
            System.out.println("I should negate X");
            x = -x;

        System.out.println(x);
    }
}
PrintAbsoluteValue.main(null);
/*
在 Java 中，花括号非常重要！与 Python 不同，
Java 语句是用花括号而不是缩进来分组的
为了演示这样做会造成哪些严重问题，请尝试运行以下程序（或使用此链接），
该程序应该打印出 的绝对值 x。然后尝试将x的值更改x为一个正数。运行程序并确保你理解为什么会出错。
!!!如果 没有花括号 {}，if 只控制 紧接着的一条语句!!!
*/

public class PrintAbsoluteValue2 {
    public static void main(String[] args) {
        int x = 5;

        if (x < 0){
            System.out.println("I should negate X");
            x = -x;            
        }


        System.out.println(x);
    }
}
PrintAbsoluteValue2.main(null);
// Out:
// -5
// 5

// %%
int bottles = 99;
while (bottles > 0) {
    System.out.println(bottles + " bottles of beer on the wall.");
    bottles = bottles - 1;
}
// Out:
// 99 bottles of beer on the wall.
// 98 bottles of beer on the wall.
// 97 bottles of beer on the wall.
// 96 bottles of beer on the wall.
// 95 bottles of beer on the wall.
// 94 bottles of beer on the wall.
// 93 bottles of beer on the wall.
// 92 bottles of beer on the wall.
// 91 bottles of beer on the wall.
// 90 bottles of beer on the wall.
// 89 bottles of beer on the wall.
// 88 bottles of beer on the wall.
// 87 bottles of beer on the wall.
// 86 bottles of beer on the wall.
// 85 bottles of beer on the wall.
// 84 bottles of beer on the wall.
// 83 bottles of beer on the wall.
// 82 bottles of beer on the wall.
// 81 bottles of beer on the wall.
// 80 bottles of beer on the wall.
// 79 bottles of beer on the wall.
// 78 bottles of beer on the wall.
// 77 bottles of beer on the wall.
// 76 bottles of beer on the wall.
// 75 bottles of beer on the wall.
// 74 bottles of beer on the wall.
// 73 bottles of beer on the wall.
// 72 bottles of beer on the wall.
// ...

// %%
int bottles = 5;
while (bottles > 0) {
    bottles = -312;
    System.out.println(bottles + " bottles of beer on the wall.");
}
// Out:
// -312 bottles of beer on the wall.

// %%
String a = "Achilles";
String t = "Tortoise";
double aPos = 0;
double tPos = 100;
double aSpeed = 20;
double tSpeed = 10;
double totalTime = 0;
while (aPos < tPos) { 
    System.out.println("At time: " + totalTime);
    System.out.println("    " + a + " is at position " + aPos);
    System.out.println("    " + t + " is at position " + tPos);

    double timeToReach = (tPos - aPos) / aSpeed;
    totalTime = totalTime + timeToReach;
    aPos = aPos + timeToReach * aSpeed;
    tPos = tPos + timeToReach * tSpeed;
}
// Out:
// At time: 0.0
//     Achilles is at position 0.0
//     Tortoise is at position 100.0
// At time: 5.0
//     Achilles is at position 100.0
//     Tortoise is at position 150.0
// At time: 7.5
//     Achilles is at position 150.0
//     Tortoise is at position 175.0
// At time: 8.75
//     Achilles is at position 175.0
//     Tortoise is at position 187.5
// At time: 9.375
//     Achilles is at position 187.5
//     Tortoise is at position 193.75
// At time: 9.6875
//     Achilles is at position 193.75
//     Tortoise is at position 196.875
// At time: 9.84375
//     Achilles is at position 196.875
//     Tortoise is at position 198.4375
// At time: 9.921875
//     Achilles is at position 198.4375
//     Tortoise is at position 199.21875
// At time: 9.9609375
//     Achilles is at position 199.21875
//     Tortoise is at position 199.609375
// At time: 9.98046875
//     Achilles is at position 199.609375
//     Tortoise is at position 199.8046875
// At time: 9.990234375
// ...

// %%
int count = 0;
String stars = "";
while (count <= 5) {
    count = count + 1;
    stars = stars + "*";
    System.out.println(stars);
}
// Out:
// *
// **
// ***
// ****
// *****
// ******

// %%
int[] numbers = new int[3];
numbers[0] = 4;
numbers[1] = 7;
numbers[2] = 10;
System.out.println(numbers[1]);
// Out:
// 7

// %%
int[] numbers = new int[]{1,22,333};
System.out.println(numbers[1]);
// Out:
// 22

// %%
public class MaxInArray {
    /** Returns the maximum value from m. */
    public static int max(int[] m) {
        int maxValue = m[0];
        for (int i = 1; i < m.length; i++) {
            if (m[i] > maxValue) {
                maxValue = m[i];
            }
        }
        return maxValue;
    }
    public static void main(String[] args) {
       int[] numbers = new int[]{9, 2, 15, 2, 222, 10, 6};
       System.out.println(max(numbers));      
    }
}
MaxInArray.main(null);
// Out:
// 222

// %%
public class ClassNameHere {
    /** Uses a while loop to sum a. */
    public static int whileSum(int[] a){
        int i = 0;
        int sum = 0;
        while (i<a.length) {
            sum = sum + a[i];
            i = i + 1;  
        }
        return sum;
    }
    public static void main(String[] args) {
       int[] numbers = new int[]{9, 2, 15, 2, 22, 10, 6};
       System.out.println(whileSum(numbers));      
    }
}
/*注意一定要包含了main*/
ClassNameHere.main(null);
// Out:
// 66

// %%
public class ClassNameHere {
    /** Uses a basic for loop to sum a. */
    public static int sum(int[] a) {
      int sum = 0;
      for (int i=0; i < a.length; i = i +1) { 
        sum = sum + a[i];
      }
      return sum;
    }
    public static void main(String[] args) {
       int[] numbers = new int[]{9, 2, 15, 2, 22, 10, 6};
       System.out.println(sum(numbers));      
    }   
}
ClassNameHere.main(null);

/*
for (initialization; termination; increment) {
    statement(s)
}
*/
// Out:
// 66

// %%
public class ContinueDemo {
    public static void main(String[] args) {
        String[] a = {"cat", "dog", "laser horse", "ketchup", "horse", "horbse"};

        for (int i = 0; i < a.length; i += 1) {
            if (a[i].contains("horse")) {
                continue;
            }
            for (int j = 0; j < 3; j += 1) {
                System.out.println(a[i]);
            }
        }
    }
}
ContinueDemo.main(null);
// Out:
// cat
// cat
// cat
// dog
// dog
// dog
// ketchup
// ketchup
// ketchup
// horbse
// horbse
// horbse

// %%
public class BreakDemo {
    public static void main(String[] args) {
        String[] a = {"cat", "dog", "laser horse", "ketchup", "horse", "horbse"};

        for (int i = 0; i < a.length; i += 1) {
            for (int j = 0; j < 3; j += 1) {
                System.out.println(a[i]);
                if (a[i].contains("horse")) {
                    break;
                }                
            }
        }
    }
}
BreakDemo.main(null);
// Out:
// cat
// cat
// cat
// dog
// dog
// dog
// laser horse
// ketchup
// ketchup
// ketchup
// horse
// horbse
// horbse
// horbse

// %%
public class WindowPosSum {
    public static void windowPosSum(int[] a, int n) {
        for (int i = 0; i < a.length; i++) {
            if (a[i] > 0) {
                int sum = 0;
                for (int j = i; j <= i + n && j < a.length; j++) {
                    sum += a[j];
                }
                a[i] = sum;
            }
        }
    }
    public static void main(String[] args) {
        int[] a = {1, 2, -3, 4, 5, 4};
        windowPosSum(a, 3);
        for (int x : a) {
            System.out.print(x + " ");
        }
    }
}
WindowPosSum.main(null);
// Out:
// 4 8 -3 13 9 4

// %%
public class EnhancedForBreakDemo {
    public static void main(String[] args) {
        String[] a = {"cat", "dog", "laser horse", "ketchup", "horse", "horbse"};

        for (String s : a) {
            for (int j = 0; j < 3; j += 1) {
                System.out.println(s);
                if (s.contains("horse")) {
                    break;
                }                
            }
        }
    }
}
EnhancedForBreakDemo.main(null);
// Out:
// cat
// cat
// cat
// dog
// dog
// dog
// laser horse
// ketchup
// ketchup
// ketchup
// horse
// horbse
// horbse
// horbse
