# %%
# Transfer Learning
# Option 1: Only train the last layer(s) of the model
# Option 2: Fine-tune the entire model (or a portion of it)

# Pre-trained models are often trained on large datasets (e.g., ImageNet) and can be used for various tasks with smaller datasets.
# They can save time and computational resources, as they have already learned useful features from the data

# %%
# Error metrics for skewed data:
# Precision: TP true positives / (TP  + FP false positives) 其实就是在所有被分类为正例的样本中真正是正例的比例
# Recall: TP true positives  / (TP + FN false negatives) 其实就是所有正例中被正确分类的比例
# F1 Score: 2 * (Precision * Recall) / (Precision + Recall) 其实就是Precision和Recall的调和平均数，综合考虑了两者的表现
# ROC Curve: Plots True Positive Rate (TPR) vs. False Positive Rate (FPR) at various threshold settings
# AUC (Area Under the Curve): Measures the overall performance of a binary classifier; higher is better
